-- %% [markdown]
-- USE TSQLV4 database to test the queries using the TSQLV4 database to demonstrate that they work.

-- %%
USE TSQLV4;
GO
SELECT *
FROM Sales.Orders 

USE Northwinds2022TSQLV7;
GO
SELECT *
FROM Sales.[Order]
-- Out:
-- Commands completed successfully.
-- (830 rows affected)
-- (830 rows affected)
-- Total execution time: 00:00:00.027
-- ...

-- %% [markdown]
-- <span style="--z-index-notebook-progress-bar: 5; --z-index-notebook-list-insertion-indicator: 10; --z-index-notebook-cell-editor-outline: 20; --z-index-notebook-scrollbar: 25; --z-index-notebook-cell-status: 26; --z-index-notebook-cell-drag-handle: 26; --z-index-notebook-folding-indicator: 26; --z-index-notebook-output: 27; --z-index-notebook-cell-bottom-toolbar-container: 28; --z-index-notebook-run-button-container: 29; --z-index-notebook-input-collapse-condicon: 29; --z-index-notebook-cell-output-toolbar: 30; --z-index-notebook-cell-toolbar: 36; color: rgb(0, 128, 0);">-- 1</span>
--
-- <span style="--z-index-notebook-progress-bar: 5; --z-index-notebook-list-insertion-indicator: 10; --z-index-notebook-cell-editor-outline: 20; --z-index-notebook-scrollbar: 25; --z-index-notebook-cell-status: 26; --z-index-notebook-cell-drag-handle: 26; --z-index-notebook-folding-indicator: 26; --z-index-notebook-output: 27; --z-index-notebook-cell-bottom-toolbar-container: 28; --z-index-notebook-run-button-container: 29; --z-index-notebook-input-collapse-condicon: 29; --z-index-notebook-cell-output-toolbar: 30; --z-index-notebook-cell-toolbar: 36; color: rgb(0, 128, 0);">-- Return orders placed in June 2015</span>
--
-- <span style="--z-index-notebook-progress-bar: 5; --z-index-notebook-list-insertion-indicator: 10; --z-index-notebook-cell-editor-outline: 20; --z-index-notebook-scrollbar: 25; --z-index-notebook-cell-status: 26; --z-index-notebook-cell-drag-handle: 26; --z-index-notebook-folding-indicator: 26; --z-index-notebook-output: 27; --z-index-notebook-cell-bottom-toolbar-container: 28; --z-index-notebook-run-button-container: 29; --z-index-notebook-input-collapse-condicon: 29; --z-index-notebook-cell-output-toolbar: 30; --z-index-notebook-cell-toolbar: 36; color: rgb(0, 128, 0);">-- Tables involved: TSQLV4 database, Sales.Orders table</span>

-- %%
USE TSQLV4;
GO
SELECT orderid, orderdate, custid, empid  
FROM Sales.Orders 
WHERE orderdate BETWEEN '2015-06-01' AND '2015-06-30';

-- WHERE is equivalent to IF statement 

USE Northwinds2022TSQLV7;
GO
SELECT OrderID,Orderdate,customerID, EmployeeID 
FROM Sales.[Order] 
WHERE orderdate BETWEEN '2015-06-01' AND '2015-06-30';
-- Out:
-- Commands completed successfully.
-- (30 rows affected)
-- (30 rows affected)
-- Total execution time: 00:00:00.088
-- ...

-- %% [markdown]
-- <span style="--z-index-notebook-progress-bar: 5; --z-index-notebook-list-insertion-indicator: 10; --z-index-notebook-cell-editor-outline: 20; --z-index-notebook-scrollbar: 25; --z-index-notebook-cell-status: 26; --z-index-notebook-cell-drag-handle: 26; --z-index-notebook-folding-indicator: 26; --z-index-notebook-output: 27; --z-index-notebook-cell-bottom-toolbar-container: 28; --z-index-notebook-run-button-container: 29; --z-index-notebook-input-collapse-condicon: 29; --z-index-notebook-cell-output-toolbar: 30; --z-index-notebook-cell-toolbar: 36; color: rgb(0, 128, 0);">-- 2</span>
--
-- <span style="--z-index-notebook-progress-bar: 5; --z-index-notebook-list-insertion-indicator: 10; --z-index-notebook-cell-editor-outline: 20; --z-index-notebook-scrollbar: 25; --z-index-notebook-cell-status: 26; --z-index-notebook-cell-drag-handle: 26; --z-index-notebook-folding-indicator: 26; --z-index-notebook-output: 27; --z-index-notebook-cell-bottom-toolbar-container: 28; --z-index-notebook-run-button-container: 29; --z-index-notebook-input-collapse-condicon: 29; --z-index-notebook-cell-output-toolbar: 30; --z-index-notebook-cell-toolbar: 36; color: rgb(0, 128, 0);">-- Return orders placed on the last day of the month</span>
--
-- <span style="--z-index-notebook-progress-bar: 5; --z-index-notebook-list-insertion-indicator: 10; --z-index-notebook-cell-editor-outline: 20; --z-index-notebook-scrollbar: 25; --z-index-notebook-cell-status: 26; --z-index-notebook-cell-drag-handle: 26; --z-index-notebook-folding-indicator: 26; --z-index-notebook-output: 27; --z-index-notebook-cell-bottom-toolbar-container: 28; --z-index-notebook-run-button-container: 29; --z-index-notebook-input-collapse-condicon: 29; --z-index-notebook-cell-output-toolbar: 30; --z-index-notebook-cell-toolbar: 36; color: rgb(0, 128, 0);">-- Tables involved: Sales.Orders table</span>

-- %%
USE TSQLV4;
GO
SELECT orderid, orderdate, custid, empid  
FROM Sales.Orders 
WHERE orderdate = EOMONTH(orderdate);
--EOMONTH() End of the month 
USE Northwinds2022TSQLV7;
GO
SELECT OrderID,Orderdate,CustomerID, EmployeeID
FROM Sales.[Order] 
WHERE orderdate = EOMONTH(orderdate);
-- Out:
-- (26 rows affected)
-- (26 rows affected)
-- Total execution time: 00:00:00.036
-- ...

-- %% [markdown]
-- <span style="color: #008000;">-- 3</span>
--
-- <span style="color: #008000;">-- Return employees with last name containing the letter 'e' twice or more</span>
--
-- <span style="color: #008000;">-- Tables involved: HR.Employees table</span>
--
-- <span style="color: #008000;"><br></span>

-- %%
USE TSQLV4;
GO
SELECT empid,firstname,lastname 
FROM HR.Employees
WHERE lastname LIKE '%e%%e%'
--LIKE equivalent to hashmap containKeys() method, if we need e contained in the column anywhere then %e%, twice then %e%%e%
USE Northwinds2022TSQLV7;
GO
SELECT Employeeid,EmployeeFirstName,EmployeeLastName 
FROM HumanResources.Employee
WHERE EmployeeLastName LIKE '%e%%e%'
-- Out:
-- Commands completed successfully.
-- (2 rows affected)
-- (2 rows affected)
-- Total execution time: 00:00:00.054
-- <table><tr><th>empid</th><th>firstname</th><th>lastname</th></tr><tr><td>4</td><td>Yael</td><td>Peled</td></tr><tr><td>5</td><td>Sven</td><td>Mortensen</td></tr></table>
-- <table><tr><th>Employeeid</th><th>EmployeeFirstName</th><th>EmployeeLastName</th></tr><tr><td>4</td><td>Yael</td><td>Peled</td></tr><tr><td>5</td><td>Sven</td><td>Mortensen</td></tr></table>

-- %% [markdown]
-- <span style="--z-index-notebook-progress-bar: 5; --z-index-notebook-list-insertion-indicator: 10; --z-index-notebook-cell-editor-outline: 20; --z-index-notebook-scrollbar: 25; --z-index-notebook-cell-status: 26; --z-index-notebook-cell-drag-handle: 26; --z-index-notebook-folding-indicator: 26; --z-index-notebook-output: 27; --z-index-notebook-cell-bottom-toolbar-container: 28; --z-index-notebook-run-button-container: 29; --z-index-notebook-input-collapse-condicon: 29; --z-index-notebook-cell-output-toolbar: 30; --z-index-notebook-cell-toolbar: 36; color: rgb(0, 128, 0);">-- 4</span>
--
-- <span style="--z-index-notebook-progress-bar: 5; --z-index-notebook-list-insertion-indicator: 10; --z-index-notebook-cell-editor-outline: 20; --z-index-notebook-scrollbar: 25; --z-index-notebook-cell-status: 26; --z-index-notebook-cell-drag-handle: 26; --z-index-notebook-folding-indicator: 26; --z-index-notebook-output: 27; --z-index-notebook-cell-bottom-toolbar-container: 28; --z-index-notebook-run-button-container: 29; --z-index-notebook-input-collapse-condicon: 29; --z-index-notebook-cell-output-toolbar: 30; --z-index-notebook-cell-toolbar: 36; color: rgb(0, 128, 0);">-- Return orders with total value(qty*unitprice) greater than 10000</span>
--
-- <span style="--z-index-notebook-progress-bar: 5; --z-index-notebook-list-insertion-indicator: 10; --z-index-notebook-cell-editor-outline: 20; --z-index-notebook-scrollbar: 25; --z-index-notebook-cell-status: 26; --z-index-notebook-cell-drag-handle: 26; --z-index-notebook-folding-indicator: 26; --z-index-notebook-output: 27; --z-index-notebook-cell-bottom-toolbar-container: 28; --z-index-notebook-run-button-container: 29; --z-index-notebook-input-collapse-condicon: 29; --z-index-notebook-cell-output-toolbar: 30; --z-index-notebook-cell-toolbar: 36; color: rgb(0, 128, 0);">-- sorted by total value</span>
--
-- <span style="--z-index-notebook-progress-bar: 5; --z-index-notebook-list-insertion-indicator: 10; --z-index-notebook-cell-editor-outline: 20; --z-index-notebook-scrollbar: 25; --z-index-notebook-cell-status: 26; --z-index-notebook-cell-drag-handle: 26; --z-index-notebook-folding-indicator: 26; --z-index-notebook-output: 27; --z-index-notebook-cell-bottom-toolbar-container: 28; --z-index-notebook-run-button-container: 29; --z-index-notebook-input-collapse-condicon: 29; --z-index-notebook-cell-output-toolbar: 30; --z-index-notebook-cell-toolbar: 36; color: rgb(0, 128, 0);">-- Tables involved: Sales.OrderDetails table</span>

-- %%
USE TSQLV4;
GO
SELECT orderid, qty*unitprice 
AS totalvalue 
FROM Sales.OrderDetails
WHERE qty*unitprice> 10000
ORDER BY totalvalue DESC;
--WHERE = IF statement, mentioned that we cant not use totalvalue in WHERE Statement which talked about it in class, because this queries has not finished yet
--DESC = descending/highest to lowest
USE Northwinds2022TSQLV7
GO
SELECT OrderId, Quantity*UnitPrice 
AS totalvalue 
FROM Sales.OrderDetail
WHERE Quantity*unitprice > 10000
ORDER BY totalvalue DESC;
-- Out:
-- Commands completed successfully.
-- (6 rows affected)
-- (6 rows affected)
-- Total execution time: 00:00:00.006
-- <table><tr><th>orderid</th><th>totalvalue</th></tr><tr><td>10865</td><td>15810.00</td></tr><tr><td>10981</td><td>15810.00</td></tr><tr><td>10889</td><td>10540.00</td></tr><tr><td>10353</td><td>10540.00</td></tr><tr><td>10417</td><td>10540.00</td></tr><tr><td>10424</td><td>10329.20</td></tr></table>
-- <table><tr><th>OrderId</th><th>totalvalue</th></tr><tr><td>10865</td><td>15810.00</td></tr><tr><td>10981</td><td>15810.00</td></tr><tr><td>10889</td><td>10540.00</td></tr><tr><td>10353</td><td>10540.00</td></tr><tr><td>10417</td><td>10540.00</td></tr><tr><td>10424</td><td>10329.20</td></tr></table>

-- %% [markdown]
-- <span style="color: #008000;">-- 5</span>
--
-- <span style="color: #008000;">-- Write a query against the HR.Employees table that returns employees</span>
--
-- <span style="color: #008000;">-- with a last name that starts with a lower case letter.</span>
--
-- <span style="color: #008000;">-- Remember that the collation of the sample database</span>
--
-- <span style="color: #008000;">-- is case insensitive (Latin1_General_CI_AS).</span>
--
-- <span style="color: #008000;">-- For simplicity, you can assume that only English letters are used</span>
--
-- <span style="color: #008000;">-- in the employee last names.</span>
--
-- <span style="color: #008000;">-- Tables involved: Sales.OrderDetails table</span>

-- %%
USE TSQLV4;
GO
SELECT empid, lastname
FROM HR.Employees
WHERE lastname COLLATE Latin1_General_CS_AS 
--LIKE N'[a-z]%' does not work, we must use exactly lower case 26 letters here;
LIKE N'[abcdefghijklmnopqrsduvwxyz]%'
--WHERE lastname COLLATE Latin1_General_CS_AS = 'davis';
USE Northwinds2022TSQLV7;
GO

SELECT EmployeeId, Employeelastname
FROM HumanResources.Employee
WHERE Employeelastname COLLATE Latin1_General_CS_AS 
LIKE N'[abcdefghijklmnopqrsduvwxyz]%'
-- Out:
-- Commands completed successfully.
-- (0 rows affected)
-- (0 rows affected)
-- Total execution time: 00:00:00.007
-- <table><tr><th>empid</th><th>lastname</th></tr></table>
-- <table><tr><th>EmployeeId</th><th>Employeelastname</th></tr></table>

-- %% [markdown]
-- <span style="color: #008000;">-- 6</span>
--
-- <span style="color: #008000;">-- Explain the difference between the following two queries</span>
--
--
--
-- <span style="color: #008000;">-- Query 1</span>
--
-- <span style="color: #0000ff;">SELECT</span> empid, <span style="color: #795e26;">COUNT</span>(<span style="color: #000000;">*</span>) <span style="color: #0000ff;">AS</span> numorders
--
-- <span style="color: #0000ff;">FROM</span> Sales.Orders
--
-- <span style="color: #0000ff;">WHERE</span> orderdate <span style="color: #000000;">&lt;</span> <span style="color: #a31515;">'20160501'</span>
--
-- <span style="color: #0000ff;">GROUP BY</span> empid;
--
--
--
-- <span style="color: #008000;">-- Query 2</span>
--
-- <span style="color: #0000ff;">SELECT</span> empid, <span style="color: #795e26;">COUNT</span>(<span style="color: #000000;">*</span>) <span style="color: #0000ff;">AS</span> numorders
--
-- <span style="color: #0000ff;">FROM</span> Sales.Orders
--
-- <span style="color: #0000ff;">GROUP BY</span> empid
--
-- <span style="color: #0000ff;">HAVING</span> <span style="color: #795e26;">MAX</span>(orderdate) <span style="color: #000000;">&lt;</span> <span style="color: #a31515;">'20160501'</span>;
--
--
--
-- ANSWER:
--
-- <span style="--z-index-notebook-progress-bar: 5; --z-index-notebook-list-insertion-indicator: 10; --z-index-notebook-cell-editor-outline: 20; --z-index-notebook-scrollbar: 25; --z-index-notebook-cell-status: 26; --z-index-notebook-cell-drag-handle: 26; --z-index-notebook-folding-indicator: 26; --z-index-notebook-output: 27; --z-index-notebook-cell-bottom-toolbar-container: 28; --z-index-notebook-run-button-container: 29; --z-index-notebook-input-collapse-condicon: 29; --z-index-notebook-cell-output-toolbar: 30; --z-index-notebook-cell-toolbar: 36; color: rgb(0, 128, 0);"><span style="color: rgb(74, 74, 74); font-size: 12px; white-space: pre;">“WHERE” clause is used to filter the records from a table that is based on a specified condition, then the “HAVING” clause is used to filter the record from the groups based on the specified condition which mean "HAVING" clause cannot be used without GROUP BY Clause.</span><br></span>

-- %% [markdown]
-- <span style="--z-index-notebook-progress-bar: 5; --z-index-notebook-list-insertion-indicator: 10; --z-index-notebook-cell-editor-outline: 20; --z-index-notebook-scrollbar: 25; --z-index-notebook-cell-status: 26; --z-index-notebook-cell-drag-handle: 26; --z-index-notebook-folding-indicator: 26; --z-index-notebook-output: 27; --z-index-notebook-cell-bottom-toolbar-container: 28; --z-index-notebook-run-button-container: 29; --z-index-notebook-input-collapse-condicon: 29; --z-index-notebook-cell-output-toolbar: 30; --z-index-notebook-cell-toolbar: 36; color: rgb(0, 128, 0);">-- 7</span>
--
-- <span style="--z-index-notebook-progress-bar: 5; --z-index-notebook-list-insertion-indicator: 10; --z-index-notebook-cell-editor-outline: 20; --z-index-notebook-scrollbar: 25; --z-index-notebook-cell-status: 26; --z-index-notebook-cell-drag-handle: 26; --z-index-notebook-folding-indicator: 26; --z-index-notebook-output: 27; --z-index-notebook-cell-bottom-toolbar-container: 28; --z-index-notebook-run-button-container: 29; --z-index-notebook-input-collapse-condicon: 29; --z-index-notebook-cell-output-toolbar: 30; --z-index-notebook-cell-toolbar: 36; color: rgb(0, 128, 0);">-- Return the three ship countries with the highest average freight for orders placed in 2015</span>
--
-- <span style="--z-index-notebook-progress-bar: 5; --z-index-notebook-list-insertion-indicator: 10; --z-index-notebook-cell-editor-outline: 20; --z-index-notebook-scrollbar: 25; --z-index-notebook-cell-status: 26; --z-index-notebook-cell-drag-handle: 26; --z-index-notebook-folding-indicator: 26; --z-index-notebook-output: 27; --z-index-notebook-cell-bottom-toolbar-container: 28; --z-index-notebook-run-button-container: 29; --z-index-notebook-input-collapse-condicon: 29; --z-index-notebook-cell-output-toolbar: 30; --z-index-notebook-cell-toolbar: 36; color: rgb(0, 128, 0);">-- Tables involved: Sales.Orders table</span>

-- %%
USE TSQLV4;
GO
SELECT TOP (3) shipcountry, AVG(freight) AS avgfreight
--AVG(freight) meaning average of entire column number in the table 
FROM Sales.Orders
WHERE orderdate > '2014' AND orderdate < '2016'
-- This condition means select year of 2015
GROUP BY shipcountry
ORDER BY avgfreight DESC;


USE Northwinds2022TSQLV7;
GO
SELECT TOP (3) ShipToCountry, AVG(fREIGHT) AS avgfreight
FROM Sales.[Order]
WHERE orderdate > '2014' AND orderdate < '2016'
GROUP BY shiptocountry
ORDER BY avgfreight DESC;
-- Out:
-- Commands completed successfully.
-- (3 rows affected)
-- (3 rows affected)
-- Total execution time: 00:00:00.024
-- <table><tr><th>shipcountry</th><th>avgfreight</th></tr><tr><td>Austria</td><td>172.4393</td></tr><tr><td>Switzerland</td><td>100.90</td></tr><tr><td>USA</td><td>93.8761</td></tr></table>
-- <table><tr><th>ShipToCountry</th><th>avgfreight</th></tr><tr><td>Austria</td><td>172.4393</td></tr><tr><td>Switzerland</td><td>100.90</td></tr><tr><td>USA</td><td>93.8761</td></tr></table>

-- %% [markdown]
-- <span style="color: #008000;">-- 8</span>
--
-- <span style="color: #008000;">-- Calculate row numbers for orders</span>
--
-- <span style="color: #008000;">-- based on order date ordering (using order id as tiebreaker)</span>
--
-- <span style="color: #008000;">-- for each customer separately</span>
--
-- <span style="color: #008000;">-- Tables involved: Sales.Orders table</span>
--
-- <span style="color: #008000;"><br></span>
--
-- <span style="color: #008000;"><br></span>
--
-- <span style="color: #0000ff;">SELECT</span> orderid, custid, val,
--
--   <span style="color: #795e26;">ROW_NUMBER</span>() <span style="color: #0000ff;">OVER</span>(<span style="color: #0000ff;">PARTITION</span> <span style="color: #0000ff;">BY</span> custid
--
--                     <span style="color: #0000ff;">ORDER BY</span> val) <span style="color: #0000ff;">AS</span> rownum
--
-- <span style="color: #0000ff;">FROM</span> Sales.OrderValues
--
-- <span style="color: #0000ff;">ORDER BY</span> custid, val;

-- %%
USE TSQLV4;
GO

SELECT custid, orderdate, orderid,
ROW_NUMBER() OVER(PARTITION BY custid ORDER BY orderdate, orderid) AS rownum
--The PARTITION BY clause divides the result set into partitions and changes how the window function is calculated. The PARTITION BY clause does not reduce the number of rows returned.
--The GROUP BY clause is used often used in conjunction with an aggregate function such as SUM() and AVG(). The GROUP BY clause reduces the number of rows returned by rolling them up and calculating the sums or averages for each group.
--The ROW_NUMBER() is a window function that assigns a sequential integer number to each row in the query’s result set.
FROM Sales.Orders
ORDER BY custid, rownum;
--First, the PARTITION BY clause distributes the Order by CustomerID.
--Second, the ORDER BY clause sorts the order in each department by orderdate, orderid in the ascending order.
--Third, the ROW_NUMBER() assigns each row a sequential integer number. It resets the number when the order changes.

USE Northwinds2022TSQLV7;
GO

SELECT CustomerID, OrderDate, OrderId,
ROW_NUMBER() OVER(PARTITION BY CustomerID ORDER BY orderdate, orderid) AS rownum
FROM Sales.[Order]
ORDER BY CustomerID, rownum;
-- Out:
-- Commands completed successfully.
-- (830 rows affected)
-- (830 rows affected)
-- Total execution time: 00:00:00.019
-- ...

-- %% [markdown]
-- <span style="color: #008000;">-- 9</span>
--
-- <span style="color: #008000;">-- Figure out and return for each employee the gender based on the title of courtesy</span>
--
-- <span style="color: #008000;">-- Ms., Mrs. - Female, Mr. - Male, Dr. - Unknown</span>
--
-- <span style="color: #008000;">-- Tables involved: HR.Employees table</span>
--
-- <span style="color: #008000;">-- CASE Expression</span>
--
-- <span style="color: #008000;">---------------------------------------------------------------------</span>
--
-- <span style="color: #008000;">-- Simple</span>
--
-- <span style="color: #0000ff;">SELECT</span> productid, productname, categoryid,
--
--   <span style="color: #0000ff;">CASE</span> categoryid
--
--     <span style="color: #0000ff;">WHEN</span> <span style="color: #09885a;">1</span> <span style="color: #0000ff;">THEN</span> <span style="color: #a31515;">'Beverages'</span>
--
--     <span style="color: #0000ff;">WHEN</span> <span style="color: #09885a;">2</span> <span style="color: #0000ff;">THEN</span> <span style="color: #a31515;">'Condiments'</span>
--
--     <span style="color: #0000ff;">WHEN</span> <span style="color: #09885a;">3</span> <span style="color: #0000ff;">THEN</span> <span style="color: #a31515;">'Confections'</span>
--
--     <span style="color: #0000ff;">WHEN</span> <span style="color: #09885a;">4</span> <span style="color: #0000ff;">THEN</span> <span style="color: #a31515;">'Dairy Products'</span>
--
--     <span style="color: #0000ff;">WHEN</span> <span style="color: #09885a;">5</span> <span style="color: #0000ff;">THEN</span> <span style="color: #a31515;">'Grains/Cereals'</span>
--
--     <span style="color: #0000ff;">WHEN</span> <span style="color: #09885a;">6</span> <span style="color: #0000ff;">THEN</span> <span style="color: #a31515;">'Meat/Poultry'</span>
--
--     <span style="color: #0000ff;">WHEN</span> <span style="color: #09885a;">7</span> <span style="color: #0000ff;">THEN</span> <span style="color: #a31515;">'Produce'</span>
--
--     <span style="color: #0000ff;">WHEN</span> <span style="color: #09885a;">8</span> <span style="color: #0000ff;">THEN</span> <span style="color: #a31515;">'Seafood'</span>
--
--     <span style="color: #0000ff;">ELSE</span> <span style="color: #a31515;">'Unknown Category'</span>
--
--   <span style="color: #0000ff;">END</span> <span style="color: #0000ff;">AS</span> categoryname
--
-- <span style="color: #0000ff;">FROM</span> Production.Products;

-- %%
USE TSQLV4;
GO
SELECT empid,firstname,lastname,titleofcourtesy, 
    CASE titleofcourtesy
    WHEN 'Ms.'  THEN 'Female'
    WHEN 'Mrs'  Then 'Female'
    WHEN 'Mr'   THEN 'Male'
    ELSE 'Unknown'
END AS gender

FROM HR.Employees
--WHEN THEN condition and result statememt 
USE Northwinds2022TSQLV7;
GO
SELECT EmployeeId,EmployeeFirstName,Employeelastname,EmployeeTitleOfCourtesy, 
    CASE EmployeeTitleOfCourtesy
    WHEN 'Ms.'  THEN 'Female'
    WHEN 'Mrs'  Then 'Female'
    WHEN 'Mr'   THEN 'Male'
    ELSE 'Unknown'
END AS gender
 
FROM HumanResources.Employee
-- Out:
-- Commands completed successfully.
-- (9 rows affected)
-- (9 rows affected)
-- Total execution time: 00:00:00.009
-- <table><tr><th>empid</th><th>firstname</th><th>lastname</th><th>titleofcourtesy</th><th>gender</th></tr><tr><td>1</td><td>Sara</td><td>Davis</td><td>Ms.</td><td>Female</td></tr><tr><td>2</td><td>Don</td><td>Funk</td><td>Dr.</td><td>Unknown</td></tr><tr><td>3</td><td>Judy</td><td>Lew</td><td>Ms.</td><td>Female</td></tr><tr><td>4</td><td>Yael</td><td>Peled</td><td>Mrs.</td><td>Unknown</td></tr><tr><td>5</td><td>Sven</td><td>Mortensen</td><td>Mr.</td><td>Unknown</td></tr><tr><td>6</td><td>Paul</td><td>Suurs</td><td>Mr.</td><td>Unknown</td></tr><tr><td>7</td><td>Russell</td><td>King</td><td>Mr.</td><td>Unknown</td></tr><tr><td>8</td><td>Maria</td><td>Cameron</td><td>Ms.</td><td>Female</td></tr><tr><td>9</td><td>Patricia</td><td>Doyle</td><td>Ms.</td><td>Female</td></tr></table>
-- ...

-- %% [markdown]
-- <span style="color: #008000;">-- 10</span>
--
-- <span style="color: #008000;">-- Return for each customer the customer ID and region</span>
--
-- <span style="color: #008000;">-- sort the rows in the output by region</span>
--
-- <span style="color: #008000;">-- having NULLs sort last (after non-NULL values)</span>
--
-- <span style="color: #008000;">-- Note that the default in T-SQL is that NULLs sort first</span>
--
-- <span style="color: #008000;">-- Tables involved: Sales.Customers table</span>

-- %%
USE TSQLV4;
GO
SELECT custid, region
FROM Sales.Customers
ORDER BY
  CASE WHEN region IS NULL THEN 1 ELSE 0 END,region;
-- When region is null, we give it a number 1 else 0; Because 1>0, null always sorted behind non null countries

USE Northwinds2022TSQLV7;
GO
SELECT CustomerId, CustomerRegion
FROM Sales.Customer
ORDER BY
  CASE WHEN CustomerRegion IS NULL THEN 1 ELSE 0 END,CustomerRegion;
-- Out:
-- Commands completed successfully.
-- (91 rows affected)
-- (91 rows affected)
-- Total execution time: 00:00:00.012
-- ...
